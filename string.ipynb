# %% [markdown]
# # String [Text]

# %% [markdown]
# string is a collection of characters in which A-Za-z0-9!@#$%%^&*(  can lie

# %% [markdown]
# S1 is a variable [bag of values ]
# = is a assignment operator

# %%
S1 = 'My name is kunal Arora' # Normal String

# %%
S1
# Out:
# 'My name is kunal Arora'

# %%
S2 = "My name is 'kunal' Arora " # Substring

# %%
S3 = '''My name is kunal Arora
Kunal Lives in Delhi''' # Multiple Line String

# %%
S3
# Out:
# 'My name is kunal Arora\nKunal Lives in Delhi'

# %%
print(S3)
# Out:
# My name is kunal Arora
# Kunal Lives in Delhi

# %%
print('kunal arora\tis a good boy') # \t is for tab
# Out:
# kunal arora	is a good boy

# %%
print('kunal arora\nis a good boy')
# Out:
# kunal arora
# is a good boy

# %%
print('kunal arora\nis a good boy\\') # \n is for new line
# Out:
# kunal arora
# is a good boy\

# %% [markdown]
# # Operators

# %% [markdown]
# ' + Concatenation * repeatation

# %%
FirstName = 'Raam'
LastName = 'Kapoor'
Sep = ' '

# %%
FirstName
# Out:
# 'Raam'

# %%
LastName
# Out:
# 'Kapoor'

# %%
FirstName + Sep + LastName
# Out:
# 'Raam Kapoor'

# %% [markdown]
# _________________
#
#     Tax Inv
# _________________

# %%
'Kunal'*10
# Out:
# 'KunalKunalKunalKunalKunalKunalKunalKunalKunalKunal'

# %%
'Sorry '*100
# Out:
# 'Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry Sorry '

# %%
Pat = '_'
Content = 'Tax Invoice'
N = '\n'

# %%
Text = Pat*30  + N + N  + Content.center(30) + N + Pat*30

# %%
Text
# Out:
# '______________________________\n\n         Tax Invoice          \n______________________________'

# %%
'_'*30
# Out:
# '______________________________'

# %%
print(Text)
# Out:
# ______________________________
#
#          Tax Invoice
# ______________________________

# %%
FullName = 'Kunal Arora'

# %%
print(f'My name is {FullName}')
# Out:
# My name is Kunal Arora

# %%
f'total of 17 + 17 is {15+17}'
# Out:
# 'total of 17 + 17 is 32'

# %%
f'17x5={17*5}'
# Out:
# '17x5=85'
